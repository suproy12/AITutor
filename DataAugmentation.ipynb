# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage import io
import os

# %%
datagen = ImageDataGenerator(
        rotation_range=45,     #Random rotation between 0 and 45
        width_shift_range=0.2,   #% shift
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest', cval=125)    #Also try nearest, constant, reflect, wrap

# %%
file_dir = "C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/"
aug_dir = "C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Augmented"
directory_list = list()
for root, dirs, files in os.walk("C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/", topdown=False):
    for name in dirs:
        print(name)
        file_dir_path = os.path.join(root, name)
        aug_dir_path =  os.path.join(aug_dir, name)
        print(file_dir_path)
        os.mkdir(aug_dir_path)
        print(aug_dir_path)
        i = 0
        for batch in datagen.flow_from_directory(directory='C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/', 
                                         batch_size=32,  
                                         target_size=(256,256),
                                         color_mode="grayscale",
                                         save_to_dir=aug_dir_path, 
                                         save_prefix='aug', 
                                         classes = [name],
                                         class_mode='categorical',
                                         shuffle = True) :
             i += 1
             if i > 10:
                break
# Out:
# Angry
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/Angry
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Augmented\Angry
# Found 14 images belonging to 1 classes.
# Attentive
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/Attentive
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Augmented\Attentive
# Found 23 images belonging to 1 classes.
# Disgusting
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/Disgusting
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Augmented\Disgusting
# Found 20 images belonging to 1 classes.
# Happy
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/Happy
# C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Augmented\Happy
# ...

# %%
file_dir = "C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/"

i = 0
for batch in datagen.flow_from_directory(directory='C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Amolpics/', 
                                         batch_size=32,  
                                         target_size=(48,48),
                                         color_mode="grayscale",
                                         save_to_dir="C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog/Augmented/Yawning2/", 
                                         save_prefix='aug',
                                         classes = ['Yawning2'],
                                         class_mode='categorical',
                                         shuffle = True) :
              i += 1
              if i > 10:
                break
# Out:
# Found 3335 images belonging to 1 classes.

# %%
from PIL import Image
import os
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import save_img
from tensorflow.keras.preprocessing.image import img_to_array

directory = r'C:/Users/Supra/Documents/Supravat/Documents/ISB/Capstone Project/code/Face Recog'
c=1
for root, dirs, filename in os.walk(directory):
 print(dirs)
 for name in  dirs :
  for filename in os.listdir(os.path.join(root, name)) :
    print(filename)
    if filename.endswith(".png"):
        path = os.path.join(root,name,filename)
        print(path)
        img = Image.open(path)
        newfilename = filename[0:len(filename)-4] +'.jpg'
        print(newfilename)
        newpath = os.path.join(root,name,newfilename)
        img.save(newpath)
        os.remove(path)
# Out:
# ['.ipynb_checkpoints', 'Amolpics', 'Augmented', 'images', 'photos', 'TestPic']
# DataAug-checkpoint.ipynb
# Deepface_recognition-checkpoint.ipynb
# Emotion_detect_0410-checkpoint.ipynb
# FaceDetectionLBP-checkpoint.ipynb
# faceemotion_run-checkpoint.ipynb
# Face_Recog_Validation-checkpoint.ipynb
# Facial Recognition-checkpoint.ipynb
# Resnet-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Untitled1-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Untitled4-checkpoint.ipynb
# vgg16-checkpoint.ipynb
# vgg16-Copy1-checkpoint.ipynb
# Angry
# Attentive
# Disgusting
# Happy
# Neutral
# SAD
# Sleepy
# Surprise
# Yawning
# Yawning2
# Angry
# Attentive
# Disgusting
# Happy
# Neutral
# SAD
# Sleepy
# Surprise
# Yawning
# Yawning2
# train
# validation
# photos
# Angry
# Disgust
# []
# ['Angry', 'Attentive', 'Disgusting', 'Happy', 'Neutral', 'SAD', 'Sleepy', 'Surprise', 'Yawning', 'Yawning2']
# IMG-20221005-WA0014.jpg
# IMG-20221005-WA0027.jpg
# IMG-20221005-WA0040.jpg
# IMG-20221005-WA0096.jpg
# ...
